# %% [markdown]
# # <center><font color='Green' face='Century'><u>GRIP - The Sparks Foundation</u></font></center>
# ## <center><font color='Blue' face='Century'><u>Exploratory Data Analysis - Retail</u></font></center>
#
# ![0-2.jpg](attachment:0-2.jpg)
#
# ##### <center> Internship on </center>
# ## <center><font color='Red' face='Century'><u>Data Science and Business Analytics</u></font></center>
# ## <center><font face='Century'><font color='Blue'><u>Author:</u></font> Muskaan Walia</font></center>
# ### <center><font face='Century'>Task 1 - As a business manager, try to find out the weak areas where you can work to make more profit. Perform ‘Exploratory Data Analysis’ on dataset ‘SampleSuperstore’</font></center>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
plt.style.use("ggplot")
plt.rcParams["figure.figsize"] = [14,8]

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\KIIT\Desktop\SampleSuperstore.csv")
storestyle = df.head(21)
storestyle.style.background_gradient(cmap = "RdYlBu_r")
# Out:
# <style  type="text/css" >
# #T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow0_col5,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow1_col5{
#             background-color:  #76afd2;
#             color:  #000000;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow0_col9{
#             background-color:  #5c90c2;
#             color:  #000000;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow0_col10,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow0_col11,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow1_col11,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow2_col10,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow2_col11,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow3_col12,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow4_col10,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow5_col11,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow6_col9,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow6_col11,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow9_col11,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow12_col5,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow15_col9,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow16_col11,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow17_col10,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow17_col11,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow18_col9,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow18_col10,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow18_col11{
#             background-color:  #313695;
#             color:  #f1f1f1;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow0_col12{
#             background-color:  #fcaa5f;
#             color:  #000000;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow1_col9,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow3_col10,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow9_col10,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow14_col10{
#             background-color:  #e9f6e8;
#             color:  #000000;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow1_col10,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow8_col10,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow12_col10,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow13_col10,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow15_col10,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow19_col10{
#             background-color:  #588cc0;
#             color:  #000000;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow1_col12,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow10_col9,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow10_col10,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow13_col5,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow14_col11,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow15_col11{
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow2_col5,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow5_col5,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow6_col5,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow7_col5,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow8_col5,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow9_col5,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow10_col5,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow11_col5{
#             background-color:  #db382b;
#             color:  #f1f1f1;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow2_col9,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow12_col9{
#             background-color:  #323896;
#             color:  #f1f1f1;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow2_col12,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow8_col12,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow12_col12,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow20_col12{
#             background-color:  #fec87a;
#             color:  #000000;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow3_col5,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow4_col5{
#             background-color:  #4065ac;
#             color:  #f1f1f1;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow3_col9{
#             background-color:  #feeca2;
#             color:  #000000;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow3_col11{
#             background-color:  #feeba1;
#             color:  #000000;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow4_col9,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow8_col9{
#             background-color:  #333b97;
#             color:  #f1f1f1;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow4_col11,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow7_col11,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow8_col11,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow10_col11,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow11_col11,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow12_col11,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow13_col11,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow19_col11,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow20_col11{
#             background-color:  #90c3dd;
#             color:  #000000;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow4_col12,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow6_col12,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow18_col12{
#             background-color:  #fecc7e;
#             color:  #000000;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow5_col9{
#             background-color:  #36459c;
#             color:  #f1f1f1;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow5_col10{
#             background-color:  #fca55d;
#             color:  #000000;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow5_col12,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow16_col12{
#             background-color:  #fdc374;
#             color:  #000000;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow6_col10,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow11_col10,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow20_col10{
#             background-color:  #a3d3e6;
#             color:  #000000;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow7_col9{
#             background-color:  #fff6b1;
#             color:  #000000;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow7_col10,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow16_col10{
#             background-color:  #fee99d;
#             color:  #000000;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow7_col12{
#             background-color:  #f57547;
#             color:  #000000;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow9_col9{
#             background-color:  #3e5ea8;
#             color:  #f1f1f1;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow9_col12{
#             background-color:  #fdb164;
#             color:  #000000;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow10_col12{
#             background-color:  #f67c4a;
#             color:  #000000;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow11_col9{
#             background-color:  #fff5af;
#             color:  #000000;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow11_col12{
#             background-color:  #f98e52;
#             color:  #000000;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow13_col9{
#             background-color:  #87bdd9;
#             color:  #000000;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow13_col12{
#             background-color:  #e34933;
#             color:  #f1f1f1;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow14_col5,#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow15_col5{
#             background-color:  #fdb567;
#             color:  #000000;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow14_col9{
#             background-color:  #384ca0;
#             color:  #f1f1f1;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow14_col12{
#             background-color:  #eaf7e6;
#             color:  #000000;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow15_col12{
#             background-color:  #fed081;
#             color:  #000000;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow16_col5{
#             background-color:  #cdeaf3;
#             color:  #000000;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow16_col9{
#             background-color:  #daf0f6;
#             color:  #000000;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow17_col5{
#             background-color:  #f46d43;
#             color:  #000000;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow17_col9{
#             background-color:  #36479e;
#             color:  #f1f1f1;
#         }#T_6b1ae8a7_2b71_11eb_bf8d_144f8a1f972arow17_col12{

# %%
df.head() #first 5 values
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
df.tail() #last 5 values
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# 9991       0.2  19.3932
# 9992       0.0  13.3200
# 9993       0.0  72.9480

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.duplicated().sum()
# Out:
# 17

# %%
df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
df.describe().style.background_gradient(cmap = "coolwarm_r")
# Out:
# <style  type="text/css" >
# #T_6b33666f_2b71_11eb_8657_144f8a1f972arow0_col0{
#             background-color:  #d44e41;
#             color:  #000000;
#         }#T_6b33666f_2b71_11eb_8657_144f8a1f972arow0_col1{
#             background-color:  #ead4c8;
#             color:  #000000;
#         }#T_6b33666f_2b71_11eb_8657_144f8a1f972arow0_col2,#T_6b33666f_2b71_11eb_8657_144f8a1f972arow0_col3,#T_6b33666f_2b71_11eb_8657_144f8a1f972arow0_col4,#T_6b33666f_2b71_11eb_8657_144f8a1f972arow7_col0,#T_6b33666f_2b71_11eb_8657_144f8a1f972arow7_col1{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_6b33666f_2b71_11eb_8657_144f8a1f972arow1_col0{
#             background-color:  #cedaeb;
#             color:  #000000;
#         }#T_6b33666f_2b71_11eb_8657_144f8a1f972arow1_col1,#T_6b33666f_2b71_11eb_8657_144f8a1f972arow6_col1{
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }#T_6b33666f_2b71_11eb_8657_144f8a1f972arow1_col2,#T_6b33666f_2b71_11eb_8657_144f8a1f972arow1_col3,#T_6b33666f_2b71_11eb_8657_144f8a1f972arow2_col2,#T_6b33666f_2b71_11eb_8657_144f8a1f972arow2_col3,#T_6b33666f_2b71_11eb_8657_144f8a1f972arow3_col0,#T_6b33666f_2b71_11eb_8657_144f8a1f972arow3_col1,#T_6b33666f_2b71_11eb_8657_144f8a1f972arow3_col2,#T_6b33666f_2b71_11eb_8657_144f8a1f972arow3_col3,#T_6b33666f_2b71_11eb_8657_144f8a1f972arow3_col4,#T_6b33666f_2b71_11eb_8657_144f8a1f972arow4_col1,#T_6b33666f_2b71_11eb_8657_144f8a1f972arow4_col2,#T_6b33666f_2b71_11eb_8657_144f8a1f972arow4_col3,#T_6b33666f_2b71_11eb_8657_144f8a1f972arow5_col1,#T_6b33666f_2b71_11eb_8657_144f8a1f972arow5_col2,#T_6b33666f_2b71_11eb_8657_144f8a1f972arow5_col3,#T_6b33666f_2b71_11eb_8657_144f8a1f972arow6_col2,#T_6b33666f_2b71_11eb_8657_144f8a1f972arow6_col3,#T_6b33666f_2b71_11eb_8657_144f8a1f972arow7_col2,#T_6b33666f_2b71_11eb_8657_144f8a1f972arow7_col3{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_6b33666f_2b71_11eb_8657_144f8a1f972arow1_col4,#T_6b33666f_2b71_11eb_8657_144f8a1f972arow6_col4{
#             background-color:  #f2cbb7;
#             color:  #000000;
#         }#T_6b33666f_2b71_11eb_8657_144f8a1f972arow2_col0{
#             background-color:  #f7b194;
#             color:  #000000;
#         }#T_6b33666f_2b71_11eb_8657_144f8a1f972arow2_col1{
#             background-color:  #be242e;
#             color:  #f1f1f1;
#         }#T_6b33666f_2b71_11eb_8657_144f8a1f972arow2_col4{
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }#T_6b33666f_2b71_11eb_8657_144f8a1f972arow4_col0{
#             background-color:  #f18f71;
#             color:  #000000;
#         }#T_6b33666f_2b71_11eb_8657_144f8a1f972arow4_col4,#T_6b33666f_2b71_11eb_8657_144f8a1f972arow5_col4{
#             background-color:  #f2cab5;
#             color:  #000000;
#         }#T_6b33666f_2b71_11eb_8657_144f8a1f972arow5_col0{
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }#T_6b33666f_2b71_11eb_8657_144f8a1f972arow6_col0,#T_6b33666f_2b71_11eb_8657_144f8a1f972arow7_col4{
#             background-color:  #5875e1;
#             color:  #000000;
#         }</style><table id="T_6b33666f_2b71_11eb_8657_144f8a1f972a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Postal Code</th>        <th class="col_heading level0 col1" >Sales</th>        <th class="col_heading level0 col2" >Quantity</th>        <th class="col_heading level0 col3" >Discount</th>        <th class="col_heading level0 col4" >Profit</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6b33666f_2b71_11eb_8657_144f8a1f972alevel0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_6b33666f_2b71_11eb_8657_144f8a1f972arow0_col0" class="data row0 col0" >9994.000000</td>
#                         <td id="T_6b33666f_2b71_11eb_8657_144f8a1f972arow0_col1" class="data row0 col1" >9994.000000</td>
#                         <td id="T_6b33666f_2b71_11eb_8657_144f8a1f972arow0_col2" class="data row0 col2" >9994.000000</td>
#                         <td id="T_6b33666f_2b71_11eb_8657_144f8a1f972arow0_col3" class="data row0 col3" >9994.000000</td>
#                         <td id="T_6b33666f_2b71_11eb_8657_144f8a1f972arow0_col4" class="data row0 col4" >9994.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_6b33666f_2b71_11eb_8657_144f8a1f972alevel0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_6b33666f_2b71_11eb_8657_144f8a1f972arow1_col0" class="data row1 col0" >55190.379428</td>
#                         <td id="T_6b33666f_2b71_11eb_8657_144f8a1f972arow1_col1" class="data row1 col1" >229.858001</td>
#                         <td id="T_6b33666f_2b71_11eb_8657_144f8a1f972arow1_col2" class="data row1 col2" >3.789574</td>
#                         <td id="T_6b33666f_2b71_11eb_8657_144f8a1f972arow1_col3" class="data row1 col3" >0.156203</td>
#                         <td id="T_6b33666f_2b71_11eb_8657_144f8a1f972arow1_col4" class="data row1 col4" >28.656896</td>
#             </tr>
#             <tr>
#                         <th id="T_6b33666f_2b71_11eb_8657_144f8a1f972alevel0_row2" class="row_heading level0 row2" >std</th>
#                         <td id="T_6b33666f_2b71_11eb_8657_144f8a1f972arow2_col0" class="data row2 col0" >32063.693350</td>
#                         <td id="T_6b33666f_2b71_11eb_8657_144f8a1f972arow2_col1" class="data row2 col1" >623.245101</td>
#                         <td id="T_6b33666f_2b71_11eb_8657_144f8a1f972arow2_col2" class="data row2 col2" >2.225110</td>
#                         <td id="T_6b33666f_2b71_11eb_8657_144f8a1f972arow2_col3" class="data row2 col3" >0.206452</td>
#                         <td id="T_6b33666f_2b71_11eb_8657_144f8a1f972arow2_col4" class="data row2 col4" >234.260108</td>
#             </tr>
#             <tr>
#                         <th id="T_6b33666f_2b71_11eb_8657_144f8a1f972alevel0_row3" class="row_heading level0 row3" >min</th>
#                         <td id="T_6b33666f_2b71_11eb_8657_144f8a1f972arow3_col0" class="data row3 col0" >1040.000000</td>
#                         <td id="T_6b33666f_2b71_11eb_8657_144f8a1f972arow3_col1" class="data row3 col1" >0.444000</td>
#                         <td id="T_6b33666f_2b71_11eb_8657_144f8a1f972arow3_col2" class="data row3 col2" >1.000000</td>
#                         <td id="T_6b33666f_2b71_11eb_8657_144f8a1f972arow3_col3" class="data row3 col3" >0.000000</td>
#                         <td id="T_6b33666f_2b71_11eb_8657_144f8a1f972arow3_col4" class="data row3 col4" >-6599.978000</td>
#             </tr>
#             <tr>
#                         <th id="T_6b33666f_2b71_11eb_8657_144f8a1f972alevel0_row4" class="row_heading level0 row4" >25%</th>
#                         <td id="T_6b33666f_2b71_11eb_8657_144f8a1f972arow4_col0" class="data row4 col0" >23223.000000</td>
#                         <td id="T_6b33666f_2b71_11eb_8657_144f8a1f972arow4_col1" class="data row4 col1" >17.280000</td>
#                         <td id="T_6b33666f_2b71_11eb_8657_144f8a1f972arow4_col2" class="data row4 col2" >2.000000</td>
#                         <td id="T_6b33666f_2b71_11eb_8657_144f8a1f972arow4_col3" class="data row4 col3" >0.000000</td>
#                         <td id="T_6b33666f_2b71_11eb_8657_144f8a1f972arow4_col4" class="data row4 col4" >1.728750</td>
#             </tr>
#             <tr>
#                         <th id="T_6b33666f_2b71_11eb_8657_144f8a1f972alevel0_row5" class="row_heading level0 row5" >50%</th>
#                         <td id="T_6b33666f_2b71_11eb_8657_144f8a1f972arow5_col0" class="data row5 col0" >56430.500000</td>
#                         <td id="T_6b33666f_2b71_11eb_8657_144f8a1f972arow5_col1" class="data row5 col1" >54.490000</td>
#                         <td id="T_6b33666f_2b71_11eb_8657_144f8a1f972arow5_col2" class="data row5 col2" >3.000000</td>
#                         <td id="T_6b33666f_2b71_11eb_8657_144f8a1f972arow5_col3" class="data row5 col3" >0.200000</td>
#                         <td id="T_

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
# Checking for null cells
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# Ship Mode       9994
# Segment         9994
# Country         9994
# City            9994
# State           9994
# Postal Code     9994
# Region          9994
# Category        9994
# Sub-Category    9994
# Sales           9994
# Quantity        9994
# Discount        9994
# Profit          9994
# dtype: int64

# %%
df['Postal Code'] = df['Postal Code'].astype('object')

# %%
df.drop_duplicates(subset=None, keep='first', inplace=True)
df.duplicated().sum()
# Out:
# 0

# %%
correlation = df.corr()
sns.heatmap(correlation, annot=True, cmap='PuBu_r')
# Out:
# <AxesSubplot:>

# %%
#dropping postal code columns
df = df.drop(['Postal Code'], axis = 1)

# %%
sns.pairplot(df, hue = 'Ship Mode', palette = 'gist_heat')

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
df_second = df[df["Ship Mode"] == "Second Class"]
df_standard = df[df["Ship Mode"] == "Standard Class"]
df_first = df[df["Ship Mode"] == "First Class"]
df_same = df[df["Ship Mode"] == "Same Day"]

# %%
x = ["Second Class", "Standard Class", "First Class", "Same Day"]
y = [len(df_second.index), len(df_standard.index), len(df_first.index), len(df_same.index)]
plt.bar(x, y, color = ["gold", "crimson", "dodgerblue", "lawngreen"], edgecolor = "black")
plt.title("Ship Mode")
plt.xlabel("Ship Modes available")
plt.ylabel("Number of items shipped")
plt.grid(True)
plt.show()

# %%
plt.pie(y, labels = x, colors = ["gold", "crimson", "dodgerblue", "lawngreen"],autopct="%1.2f%%", explode=(0,0,0,0.2))
plt.title("Percentage distribution of Ship Modes")
plt.xlabel("Ship Modes available")
plt.legend()
plt.grid(True)
plt.show()

# %%
#valuecounts for segment
df['Segment'].value_counts()
# Out:
# Consumer       5183
# Corporate      3015
# Home Office    1779
# Name: Segment, dtype: int64

# %%
sns.pairplot(df, hue = 'Segment', palette = 'gist_earth_r')

# %%
df_con = df[df["Segment"] == "Consumer"]
df_corp = df[df["Segment"] == "Corporate"]
df_home = df[df["Segment"] == "Home Office"]

# %%
x = ["Consumer", "Corporate", "Home Office"]
y = [len(df_con.index), len(df_corp.index), len(df_home.index)]
plt.bar(x, y, color = ["limegreen", "gold", "dodgerblue"], edgecolor = "black")
plt.title("Types of Customers")
plt.xlabel("Customers")
plt.ylabel("Number of Customers")
plt.grid(True)
plt.show()

# %%
plt.pie(y, labels = x, colors = ["limegreen", "gold", "dodgerblue"],autopct="%1.2f%%", explode=(0,0,0.1))
plt.title("Percentage distribution of Customers")
plt.xlabel("Customers")
plt.legend()
plt.grid(True)
plt.show()

# %%
df['State'].value_counts()
# Out:
# California              1996
# New York                1127
# Texas                    983
# Pennsylvania             586
# Washington               502
# Illinois                 491
# Ohio                     468
# Florida                  383
# Michigan                 254
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   123
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# South Carolina            42
# Louisiana                 42
# Nevada                    39
# Nebraska                  38
# New Mexico                37
# Iowa                      30
# New Hampshire             27
# Kansas                    24
# Idaho                     21
# Montana                   15
# South Dakota              12
# Vermont                   11
# District of Columbia      10
# Maine                      8
# North Dakota               7
# West Virginia              4
# Wyoming                    1
# Name: State, dtype: int64

# %%
plt.figure(figsize=(18,9))
sns.countplot(x='State', data=df, palette='Spectral_r', order=df['State'].value_counts().index)
plt.title("Different States")
plt.xlabel("States")
plt.ylabel("Sales in States")
plt.xticks(rotation=90)
plt.show()

# %%
# valuecounts for region
df['Region'].value_counts()
# Out:
# West       3193
# East       2845
# Central    2319
# South      1620
# Name: Region, dtype: int64

# %%
sns.pairplot(df, hue = 'Region', palette = 'twilight')

# %%
df['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
df_south = df[df["Region"] == "South"]
df_west = df[df["Region"] == "West"]
df_central = df[df["Region"] == "Central"]
df_east = df[df["Region"] == "East"]

# %%
x = ["South", "West", "Central", "East"]
y = [len(df_south.index), len(df_west.index), len(df_central.index), len(df_east.index),]
plt.bar(x, y, color = ["cornflowerblue", "crimson", "gold", "limegreen"], edgecolor = "black")
plt.title("All the Regions Served")
plt.xlabel("Regions Served")
plt.ylabel("Number of Customers")
plt.grid(True)
plt.show()

# %%
plt.pie(y, labels = x, colors = ["cornflowerblue", "crimson", "gold", "limegreen"], autopct="%1.2f%%", explode=(0.1,0,0,0))
plt.title("Percentage of distribution of Regions Served")
plt.xlabel("Number of Customers")
plt.legend()
plt.grid(True)
plt.show()

# %%
mode_profit = df.groupby("Ship Mode")["Profit"].sum()
segment_profit = df.groupby("Segment")["Profit"].sum()
region_profit = df.groupby("Region")["Profit"].sum()
category_profit = df.groupby("Category")["Profit"].sum()

# %%
plt.plot(mode_profit, color="dodgerblue", lw=5, ls="-", marker="x", label="Different Modes", markeredgecolor="black")
plt.plot(segment_profit, color="lawngreen", lw=5, ls=":", marker="o", label="Different Segments", markeredgecolor="black")
plt.plot(region_profit, color="crimson", lw=5, ls="-.", marker="v", label="Different Regions", markeredgecolor="black")
plt.plot(category_profit, color="gold", lw=5, marker="^", label="Different Category", markeredgecolor="black")
plt.title("Profi for different Sections")
plt.xticks(rotation=90)
plt.xlabel("Different Sections")
plt.ylabel("Total Profit")
plt.legend()
plt.grid(True)
plt.show()

# %%
df["Sub-Category"].value_counts()
# Out:
# Binders        1522
# Paper          1359
# Furnishings     956
# Phones          889
# Storage         846
# Art             795
# Accessories     775
# Chairs          615
# Appliances      466
# Labels          363
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
plt.figure(figsize=(15,14))
df["Sub-Category"].value_counts().plot.pie(autopct="%1.2f%%")
plt.show()

# %%
state_sal_pro = df.groupby("State")[["Sales","Profit"]].sum().sort_values(by="Sales",ascending=False)
state_sal_pro.plot(kind="bar", color=["limegreen", "gold"], edgecolor="black")
plt.title("Profit or Loss and Sales of States")
plt.xlabel("States")
plt.ylabel("Total Profit or Loss and Sales")
plt.grid(True)
plt.show()

# %%
city_sal_pro = df.groupby("City")[["Sales","Profit"]].sum().sort_values(by="Sales",ascending=False).head(20)
city_sal_pro.plot(kind="bar", color=["mistyrose", "slateblue"], edgecolor="black")
plt.title("Profit or Loss and Sales of Top 20 Cities")
plt.xlabel("Top 20 Cities")
plt.ylabel("Total Profit or Loss and Sales")
plt.grid(True)
plt.show()

# %%
t_states = df['State'].value_counts().nlargest(10)
t_states
# Out:
# California        1996
# New York          1127
# Texas              983
# Pennsylvania       586
# Washington         502
# Illinois           491
# Ohio               468
# Florida            383
# Michigan           254
# North Carolina     249
# Name: State, dtype: int64

# %%
df.groupby("Category")[["Sales","Profit"]].sum().plot.bar(color=["gold","darkorange"],alpha=0.9,edgecolor="black")
plt.title("Profit or Loss of Categories")
plt.xlabel("Different Categories")
plt.ylabel("Profit or Loss and Sales")
plt.show()

# %%
subcat_sal_pro = df.groupby("Sub-Category")[["Sales","Profit"]].sum().sort_values(by="Sales",ascending=False)
subcat_sal_pro.plot(kind="bar", color=["dodgerblue", "crimson"], edgecolor="black")
plt.title("Profit or Loss and Sales of Sub-Categories")
plt.xlabel("Sub-Categories Ordered")
plt.ylabel("Total Profit or Loss and Sales")
plt.grid(True)
plt.show()

# %%
plt.hist(df["Sales"],bins=(np.arange(0,600,10)),color="plum",edgecolor="black")
plt.title("Histogram for Sales")
plt.xlabel("Quantity")
plt.ylabel("Profit")
# Out:
# Text(0, 0.5, 'Profit')

# %%
plt.hist(df["Profit"],bins=(np.arange(0,600,15)),color="orange",edgecolor="black")
plt.title("Histogram for Profit")
plt.xlabel("Quantity")
plt.ylabel("Profit")
# Out:
# Text(0, 0.5, 'Profit')

# %%
plt.imshow(city_sal_pro.transpose(), cmap='YlOrRd_r', interpolation='nearest')
plt.title("Heatmap for Profit and Sales for different Cities")
plt.xlabel("Profit/Loss and Sales")
plt.show()

# %%
plt.imshow(state_sal_pro.head(20).transpose(), cmap='YlOrRd_r', interpolation='nearest')
plt.title("Heatmap for Profit and Sales for different States")
plt.xlabel("Profit/Loss and Sales")
plt.show()

# %% [markdown]
# # <font color='blue' face='Century'><u>Insights Derived:</u></font>
#
# 1. Discount has no effect on Quantity sold.
# 2. Improvement needed in Same Day Shipment Mode.
# 3. Profit and Sales are maximum in consumer segment and minimum in home office segment.
# 4. Highest number of buyers are from California and New York.
# 5. Improvements needed in Southern Region.
# 6. Maximum Profits are from binders, papers, furnishings, phones, storage, art, accessories and minimum from supplies, machines, copiers(very less).
# 7. Loss in Texas, pennsylvania and Ohio.
# 8. Technology and Office Supplies have high profit whereas Furniture has less profit.
# 9. Phone sub-categories have high sales, Chairs have high sale but less profit, whereas, Tables and Bookcases sub-categories are facing huge losses.
# 10. Profit and Sales are not related.
